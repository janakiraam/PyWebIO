# %%
from pywebio.input import*
from pywebio.output import*

# %%
name= input("Enter the name here ", type="text") # On executing the line a session will be opened in a browser with 
                                                  #http://localhost:64351/
                                                  # once the seession is closed you can't change give input again. Even after
                                                  # reexecuting in any session

# %%
name
# Out:
# 'Janaki Raam'

# %%
name1= input("Enter the name here ", type="text")

# %%
name1
# Out:
# 'Janaki Raam'

# %%
# password input
password = input("Input Password", type = PASSWORD)

# Drop-Down selection
gift = select('Which gift you want?',['DataSicence','AIResearcher'])

#checkbox
agree = checkbox("User Terms", options = ['I agree terms and conditions'])

#singlechoice
answer = radio("choose one",options=['A','B','C','D'])

#multi-line text area
text = textarea('Text Area', rows=3, placeholder='Some text')

#File Upload
img = file_upload("Select a image:", accept="image/*")

# %%
put_text(answer)

# %%
img
# Out:
# {'filename': 'CNN_Paul.JPG',
#  'size': 31315,
#  'mime_type': 'image/jpeg',
#  'last_modified': 1625479634.151,
#  'dataurl': 'data:image/jpeg;base64,...',
# ...

# %%
agree
# Out:
# ['I agree terms and conditions']

# %%
password
# Out:
# 'janakiraam'

# %%
gift
# Out:
# 'AIResearcher'

# %%
def check_age(p):
    if p < 10:
        return "Too Young"
    if p > 60:
        return "Too old"
    

age = input("Please enter the age",type=NUMBER,validate=check_age)

# %%
age
# Out:
# 50

# %%
code = textarea('Code Edit', code={
    'mode': "python",  # code language
    'theme': 'darcula',  # Codemirror theme. Visit https://codemirror.net/demo/theme.html#cobalt to get more themes
}, value='import something\n# Write your python code')

# %%
code
# Out:
# 'import pandas\n# Write your python code\nprint("hello world")'

# %%
from pywebio.output import *
# Text Output
put_text("Hello world!")

# Table Output
put_table([
    ['Commodity', 'Price'],
    ['Apple', '5.5'],
    ['Banana', '7'],
])

# Markdown Output
put_markdown('~~Strikethrough~~')

# File Output
put_file('hello_word.txt', b'hello word!')

# PopUp Output
popup('popup title', 'popup text content')

# %%
with put_collapse('This is title'):
    for i in range(4):
        put_text(i)

    put_table([
        ['Commodity', 'Price'],
        ['Apple', '5.5'],
        ['Banana', '7'],
    ])
